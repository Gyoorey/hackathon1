# %%
from __future__ import print_function
import os
import neat
import visualize

# %%
# 2-input XOR inputs and expected outputs.
xor_inputs = [(21,21,21,21,21,8,21,21,21,21,21,5)]
xor_outputs = [(0,1,0)]

# %%
def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        genome.fitness = 6.0
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        
        for xi, xo in zip(xor_inputs, xor_outputs):
            output = net.activate(xi)
            #print(output)
            #genome.fitness -= (output[0] - xo[0]) ** 2

# %%
def run(config_file):
    # Load configuration.
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)

    # Create the population, which is the top-level object for a NEAT run.
    p = neat.Population(config)

    # Add a stdout reporter to show progress in the terminal.
    p.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    p.add_reporter(stats)
    p.add_reporter(neat.Checkpointer(5))

    # Run for up to 300 generations.
    winner = p.run(eval_genomes, 20)

    # Display the winning genome.
    print('\nBest genome:\n{!s}'.format(winner))

    # Show output of the most fit genome against training data.
    print('\nOutput:')
    winner_net = neat.nn.FeedForwardNetwork.create(winner, config)
    for xi, xo in zip(xor_inputs, xor_outputs):
        output = winner_net.activate(xi)
        print("input {!r}, expected output {!r}, got {!r}".format(xi, xo, output))

    node_names = {-1:'A', -2: 'B', 0:'A XOR B'}
    visualize.draw_net(config, winner, True, node_names=node_names)
    visualize.plot_stats(stats, ylog=False, view=True)
    visualize.plot_species(stats, view=True)

    p = neat.Checkpointer.restore_checkpoint('neat-checkpoint-4')
    p.run(eval_genomes, 10)

# %%
if __name__ == '__main__':
    # Determine path to configuration file. This path manipulation is
    # here so that the script will run successfully regardless of the
    # current working directory.
    local_dir = os.path.dirname(".")
    config_path = os.path.join(local_dir, 'config-feedforward')
    run(config_path)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.229, standard deviation 0.257
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   150      1.0    0.000     0
# Total extinctions: 0
# Generation time: 0.139 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 256
# Average adjusted fitness: 0.000
# Mean genetic distance 1.274, standard deviation 0.275
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1   150      1.0    0.000     1
# Total extinctions: 0
# Generation time: 0.107 sec (0.123 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 256
# Average adjusted fitness: 0.000
# Mean genetic distance 1.258, standard deviation 0.297
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2   150      1.0    0.000     2
# Total extinctions: 0
# Generation time: 0.099 sec (0.115 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 256
# Average adjusted fitness: 0.000
# Mean genetic distance 1.231, standard deviation 0.325
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3   150      1.0    0.000     3
# Total extinctions: 0
# Generation time: 0.105 sec (0.112 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.315, standard deviation 0.294
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4   150      1.0    0.000     4
# Total extinctions: 0
# Generation time: 0.106 sec (0.111 average)
# Saving checkpoint to neat-checkpoint-4
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.320, standard deviation 0.300
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5   150      1.0    0.000     5
# Total extinctions: 0
# Generation time: 0.097 sec (0.109 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.304, standard deviation 0.344
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6   150      1.0    0.000     6
# Total extinctions: 0
# Generation time: 0.101 sec (0.108 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.309, standard deviation 0.306
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7   150      1.0    0.000     7
# Total extinctions: 0
# Generation time: 0.098 sec (0.107 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.343, standard deviation 0.322
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8   150      1.0    0.000     8
# Total extinctions: 0
# Generation time: 0.131 sec (0.109 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.360, standard deviation 0.303
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9   150      1.0    0.000     9
# Total extinctions: 0
# Generation time: 0.111 sec (0.109 average)
# Saving checkpoint to neat-checkpoint-9
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.345, standard deviation 0.338
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10   150      1.0    0.000    10
# Total extinctions: 0
# Generation time: 0.108 sec (0.106 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.310, standard deviation 0.325
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11   150      1.0    0.000    11
# Total extinctions: 0
# Generation time: 0.100 sec (0.106 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.273, standard deviation 0.311
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12   150      1.0    0.000    12
# Total extinctions: 0
# Generation time: 0.078 sec (0.104 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.298, standard deviation 0.306
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13   150      1.0    0.000    13
# Total extinctions: 0
# Generation time: 0.098 sec (0.103 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.296, standard deviation 0.272
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14   150      1.0    0.000    14
# Total extinctions: 0
# Generation time: 0.101 sec (0.102 average)
# Saving checkpoint to neat-checkpoint-14
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.237, standard deviation 0.285
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15   150      1.0    0.000    15
# Total extinctions: 0
# Generation time: 0.098 sec (0.102 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.274, standard deviation 0.300
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16   150      1.0    0.000    16
# Total extinctions: 0
# Generation time: 0.130 sec (0.105 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.279, standard deviation 0.314
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17   150      1.0    0.000    17
# Total extinctions: 0
# Generation time: 0.085 sec (0.104 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.291, standard deviation 0.351
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18   150      1.0    0.000    18
# Total extinctions: 0
# Generation time: 0.102 sec (0.101 average)
#
#  ****** Running generation 19 ******
# Population's average fitness: 1.00000 stdev: 0.00000
# Best fitness: 1.00000 - size: (3, 36) - species 1 - id 512
# Average adjusted fitness: 0.000
# Mean genetic distance 1.271, standard deviation 0.309
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19   150      1.0    0.000    19
# Total extinctions: 0
# Generation time: 0.106 sec (0.101 average)
# Saving checkpoint to neat-checkpoint-19
#
# Best genome:
# Key: 1
# Fitness: 1.0
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-0.4529897215285825, response=1.0, activation=sigmoid, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=0.27404244130028294, response=1.0, activation=sigmoid, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=0.08644974907843268, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-12, 0), weight=-0.7799259682967374, enabled=True)
# 	DefaultConnectionGene(key=(-12, 1), weight=1.1700587389083659, enabled=True)
# 	DefaultConnectionGene(key=(-12, 2), weight=1.0561499868465762, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=2.425368417253967, enabled=True)
# 	DefaultConnectionGene(key=(-11, 1), weight=-0.08738997551180694, enabled=True)
# 	DefaultConnectionGene(key=(-11, 2), weight=-1.4605690529982396, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=-0.14628954447113968, enabled=True)
# 	DefaultConnectionGene(key=(-10, 1), weight=-2.29401390072248, enabled=True)
# 	DefaultConnectionGene(key=(-10, 2), weight=0.5644692540332752, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=-1.934650548668332, enabled=True)
# 	DefaultConnectionGene(key=(-9, 1), weight=-0.320778055886626, enabled=True)
# 	DefaultConnectionGene(key=(-9, 2), weight=-1.0798744309419608, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=2.2204696337339604, enabled=True)
# 	DefaultConnectionGene(key=(-8, 1), weight=-0.8531759818817597, enabled=True)
# 	DefaultConnectionGene(key=(-8, 2), weight=1.1791675195437636, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=-1.6933800531994427, enabled=True)
# 	DefaultConnectionGene(key=(-7, 1), weight=0.16532396062786353, enabled=True)
# 	DefaultConnectionGene(key=(-7, 2), weight=-0.8287444041689048, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=-0.7355526239296946, enabled=True)
# 	DefaultConnectionGene(key=(-6, 1), weight=0.8229957268404541, enabled=True)
# 	DefaultConnectionGene(key=(-6, 2), weight=-1.6145502203762432, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=2.0887818018184876, enabled=True)
# 	DefaultConnectionGene(key=(-5, 1), weight=1.7007889602210053, enabled=True)
# 	DefaultConnectionGene(key=(-5, 2), weight=1.9888184550995793, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=1.2944356223782967, enabled=True)
# 	DefaultConnectionGene(key=(-4, 1), weight=-0.22515398573974474, enabled=True)
# 	DefaultConnectionGene(key=(-4, 2), weight=0.16565469674350694, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=-0.27563869158662035, enabled=True)
# 	DefaultConnectionGene(key=(-3, 1), weight=-1.0912362258954826, enabled=True)
# 	DefaultConnectionGene(key=(-3, 2), weight=-1.0455360135472476, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=-2.656347173845072, enabled=True)
# 	DefaultConnectionGene(key=(-2, 1), weight=-0.8865148910431518, enabled=True)
# 	DefaultConnectionGene(key=(-2, 2), weight=-1.0710454130797284, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=0.8440449976526256, enabled=True)
# 	DefaultConnectionGene(key=(-1, 1), weight=-0.49714837947993795, enabled=True)
# 	DefaultConnectionGene(key=(-1, 2), weight=-1.128132546070774, enabled=True)
#
# Output:
# input (21, 21, 21, 21, 21, 8, 21, 21, 21, 21, 21, 5), expected output (0, 1, 0), got [1.0, 8.75651076269652e-27, 8.75651076269652e-27]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\users\gabor\appdata\local\programs\python\python35\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     128         try:
# --> 129             subprocess.check_call(args, stderr=stderr, **POPEN_KWARGS)
#     130         except OSError as e:
#
# c:\users\gabor\appdata\local\programs\python\python35\lib\subprocess.py in check_call(*popenargs, **kwargs)
#     578     """
# --> 579     retcode = call(*popenargs, **kwargs)
#     580     if retcode:
#
# c:\users\gabor\appdata\local\programs\python\python35\lib\subprocess.py in call(timeout, *popenargs, **kwargs)
#     559     """
# --> 560     with Popen(*popenargs, **kwargs) as p:
#     561         try:
#
# c:\users\gabor\appdata\local\programs\python\python35\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     949                                 errread, errwrite,
# --> 950                                 restore_signals, start_new_session)
#     951         except:
#
# c:\users\gabor\appdata\local\programs\python\python35\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1219                                          cwd,
# -> 1220                                          startupinfo)
#    1221             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# ExecutableNotFound                        Traceback (most recent call last)
# <ipython-input-70-a44f2eac0bf4> in <module>()
#       5     local_dir = os.path.dirname(".")
#       6     config_path = os.path.join(local_dir, 'config-feedforward')
# ----> 7     run(config_path)
#
# <ipython-input-69-d904f019d098> in run(config_file)
#      28
#      29     node_names = {-1:'A', -2: 'B', 0:'A XOR B'}
# ---> 30     visualize.draw_net(config, winner, True, node_names=node_names)
#      31     visualize.plot_stats(stats, ylog=False, view=True)
#      32     visualize.plot_species(stats, view=True)
#
# F:\USERS SSD\SZTE-PhD\[_]\Hackathon\2018.07.28. I\hackathon1\AI\neat-python-master\examples\xor\visualize.py in draw_net(config, genome, view, filename, node_names, show_disabled, prune_unused, node_colors, fmt)
#     196             dot.edge(a, b, _attributes={'style': style, 'color': color, 'penwidth': width})
#     197
# --> 198     dot.render(filename, view=view)
#     199
#     200     return dot
#
# c:\users\gabor\appdata\local\programs\python\python35\lib\site-packages\graphviz\files.py in render(self, filename, directory, view, cleanup)
#     174         filepath = self.save(filename, directory)
#     175
# --> 176         rendered = backend.render(self._engine, self._format, filepath)
#     177
#     178         if cleanup:
#
# c:\users\gabor\appdata\local\programs\python\python35\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     132                 raise ExecutableNotFound(args)
#     133             else:  # pragma: no cover
# --> 134                 raise
#     135
#     136     return rendered
#
# c:\users\gabor\appdata\local\programs\python\python35\lib\contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# c:\users\gabor\appdata\local\programs\python\python35\lib\site-packages\graphviz\backend.py in open(name, mode)
#     123         def open(name, mode):
#     124             assert name == os.devnull and mode == 'w'
# --> 125             yield None
#     126
#     127     with open(os.devnull, 'w') as stderr:
#
# c:\users\gabor\appdata\local\programs\python\python35\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     130         except OSError as e:
#     131             if e.errno == errno.ENOENT:
# --> 132                 raise ExecutableNotFound(args)
#     133             else:  # pragma: no cover
#     134                 raise
#
# ExecutableNotFound: failed to execute ['dot', '-Tsvg', '-O', 'Digraph.gv'], make sure the Graphviz executables are on your systems' PATH
